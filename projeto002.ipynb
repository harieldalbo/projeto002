# %% [markdown]
# # ANÁLISE DE PREÇOS DE PRODUTOS AGRÍCOLAS
#
# ### HARIEL
# ### IGOR
# ### JAYCE
#
# Fonte da base de dados: dados da conab referente a diversos produtos: https://www.kaggle.com/datasets/jeffersonvalandro/conab-valor-dos-produtos-no-brasil?select=relatorio_preco_medio_mensal_2023.csv

# %% [markdown]
# **A base de dados apresenta preços médios mensais de diversos produtos agrícolas coletados pela Companhia Nacional de Abastecimento (Conab). Não há uma uniformidade nos dados, não existem dados de preços em todos os estados para todos os produtos. Os preços são apresentados em três níveis de comercialização: preços ao produtor, preços no atacado e preços no varejo; também não há uniformidade nisso, a maioria dos produtos tem preços em apenas um dos níveis.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#carregando o dataframe

df = pd.read_csv('dados_conab/relatorio_preco_medio_mensal_2023.csv')

# %%
#pedindo as primeiras 20 linhas

df.head(20)
# Out:
#              Produto/Unidade Nível de Comercialização U.F.   01/2023  \
# 0               ABACATE (kg)                  ATACADO   RR      6,83
# 1         ABACAXI HAVAÍ (kg)                 PRODUTOR   PR      1,85
# 2               ABACAXI (kg)                  ATACADO   RR      2,59
# 3   ABACAXI PÉROLA (6.50 kg)                 PRODUTOR   DF     21,80
# 4        ABACAXI PÉROLA (kg)                      NaN   AM      3,81
# 5                        NaN                      NaN   AP      3,20
# 6                        NaN                      NaN   ES      2,30
# 7                        NaN                      NaN   RR      2,17
# 8         ABACAXI PÉROLA (t)                      NaN   BA       NaN
# 9                        NaN                      NaN   SP  1.587,50
# 10       ABACAXI PÉROLA (un)                  ATACADO   MT      3,96
# 11                       NaN                 PRODUTOR   AC      3,45
# 12                       NaN                      NaN   AL      1,90
# 13                       NaN                      NaN   CE      5,00
# 14                       NaN                      NaN   GO      3,05
# 15                       NaN                      NaN   MG      1,93
# 16                       NaN                      NaN   PA      2,14
# 17                       NaN                      NaN   PB      2,36
# 18                       NaN                      NaN   PE      1,46
# 19                       NaN                      NaN   RJ      2,55
#
#      02/2023   03/2023 04/2023   05/2023   06/2023   07/2023   08/2023  \
# 0       6,67      6,83    7,00      7,00      6,00      6,00      6,60
# 1       2,31      2,30    2,30      2,30       NaN       NaN       NaN
# 2       2,65      2,79    6,00      8,00      4,50      4,50      4,95
# 3      20,14     23,45   26,65     34,82     36,87     25,47     27,36
# 4       3,75      3,75    3,90      4,00      4,25      4,02      3,94
# 5       3,40      3,40    3,55      3,72      3,81      3,63      3,43
# 6       2,56      3,04    3,35      3,36      3,27      3,13      3,11
# 7       2,13      2,24    3,62      3,93      4,14      3,90      5,74
# 8        NaN       NaN     NaN  2.000,00  1.977,27  2.050,00  2.204,35
# 9   1.744,44  1.862,50     NaN       NaN       NaN       NaN       NaN
# 10      4,41      4,52    4,41      4,47      4,39      4,91      5,00
# 11      3,45      3,45    3,46      3,93      4,00      4,03      4,05
# 12      2,16       NaN     NaN      2,40      2,81      2,66      2,89
# 13      6,00       NaN     NaN       NaN       NaN       NaN       NaN
# 14      3,42      3,08    3,48      3,67      3,46      3,25      3,17
# 15      2,68      2,60    3,45      3,43      2,81      2,85      3,44
# 16      2,50      2,50    2,33      1,63      1,20      1,23      0,87
# 17      2,36      2,53    2,53      2,53      2,53      2,53      2,53
# 18      1,90      3,95    4,10      3,30      3,52      3,28      3,08
# 19      2,58      2,82    3,62      3,50      2,92      3,07      2,50
#
#      09/2023   10/2023   11/2023 12/2023
# 0       7,00      7,00      7,00    7,00
# 1        NaN       NaN      2,60    2,60
# 2       5,00      7,50      7,00    7,50
# 3      28,48     31,92     25,05   25,75
# 4       4,27      4,25      4,51    4,23
# 5       3,17       NaN      3,42    3,25
# 6       3,10      3,03      3,00    3,06
# 7       6,50      6,50      6,70    6,52
# 8   2.295,24  2.325,00  2.300,00     NaN
# 9        NaN       NaN       NaN     NaN
# 10       NaN       NaN       NaN     NaN
# 11      4,05      4,05      4,05    4,05
# 12      2,74      3,15      3,27    3,59
# 13       NaN       NaN      5,00    5,00
# 14      2,91      3,03      2,82    3,63
# 15      3,52      3,60      3,69    3,20
# 16      0,80      0,80      1,09    2,86
# 17      2,37      2,50      2,50    2,57
# 18      3,05      3,25      3,73    3,93
# 19      2,42      2,52      2,99    4,43

# %%
df.isnull().sum()
# Out:
# Produto/Unidade             1478
# Nível de Comercialização    1720
# U.F.                           5
# 01/2023                      128
# 02/2023                      127
# 03/2023                      155
# 04/2023                      155
# 05/2023                      145
# 06/2023                      150
# 07/2023                      177
# 08/2023                      248
# 09/2023                      264
# 10/2023                      323
# 11/2023                      426
# 12/2023                      450
# dtype: int64

# %% [markdown]
# **Acima vemos as primeiras 20 linhas da base de dados, as colunas Produto/Unidade e Nível de Comercialização apresentam muitos valores nulos. O motivo é que o nome de produto é apresentado na primeira linha e vale para as próximas, até que apareça outro valor, o mesmo vale para os níveis de comercialização.**

# %%
#pedindo as últimas 20 linhas

df.tail(20)
# Out:
#                                         Produto/Unidade  \
# 2009                                                NaN
# 2010                  UVA INDÚSTRIA NIÁGARA BRANCA (kg)
# 2011                         UVA INDÚSTRIA NIÁGARA (kg)
# 2012                                   UVA MOSCATO (kg)
# 2013                                   UVA NIÁGARA (kg)
# 2014                                     VACA GORDA (@)
# 2015                                 VACA GORDA (15 kg)
# 2016                                                NaN
# 2017                                                NaN
# 2018                                                NaN
# 2019                                                NaN
# 2020                                                NaN
# 2021                                                NaN
# 2022                                                NaN
# 2023                                                NaN
# 2024                                                NaN
# 2025                                                NaN
# 2026  Fonte: Companhia Nacional de Abastecimento - C...
# 2027  As informações podem ser reproduzidas, desde q...
# 2028  Proibida a comercialização das informações dis...
#
#      Nível de Comercialização U.F. 01/2023 02/2023 03/2023 04/2023 05/2023  \
# 2009                      NaN   SC     NaN    1,40    1,39    1,38    1,38
# 2010                      NaN   MG     NaN    6,36     NaN     NaN     NaN
# 2011                      NaN   SP    4,54    4,15     NaN     NaN    5,22
# 2012                      NaN   RS    2,13    2,13    2,13    2,13    1,89
# 2013                      NaN   RS    1,58    1,58    1,58    1,58    1,40
# 2014                      NaN   TO  244,46  221,85  207,12  209,71  192,51
# 2015                      NaN   DF  277,75  267,00  240,65  225,50  223,00
# 2016                      NaN   GO  252,94  240,07  228,99  232,50  203,34
# 2017                      NaN   MG  238,85  243,21  237,23  241,77  216,44
# 2018                      NaN   MS  237,25  235,61  240,22  245,75  221,48
# 2019                      NaN   MT  233,75  228,28  223,74  229,08  208,89
# 2020                      NaN   PA  244,75  232,16  228,25  231,88  218,56
# 2021                      NaN   PR  257,83  252,30  251,87  254,04  231,54
# 2022                      NaN   SE  255,00  252,75  242,83  245,00  238,26
# 2023                      NaN   SP  258,31  256,87  255,37  250,75  224,06
# 2024                      NaN  NaN     NaN     NaN     NaN     NaN     NaN
# 2025                      NaN  NaN     NaN     NaN     NaN     NaN     NaN
# 2026                      NaN  NaN     NaN     NaN     NaN     NaN     NaN
# 2027                      NaN  NaN     NaN     NaN     NaN     NaN     NaN
# 2028                      NaN  NaN     NaN     NaN     NaN     NaN     NaN
#
#      06/2023 07/2023 08/2023 09/2023 10/2023 11/2023 12/2023
# 2009     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2010     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2011    5,07    5,56    5,58    5,98    6,32    6,94    6,58
# 2012    1,89    1,89    1,89    1,89    1,89    1,89    1,89
# 2013    1,40    1,40    1,40    1,40    1,40    1,40    1,40
# 2014  174,68  185,56     NaN     NaN     NaN     NaN     NaN
# 2015  197,09  188,33     NaN     NaN     NaN     NaN     NaN
# 2016  190,54  203,67     NaN     NaN     NaN     NaN     NaN
# 2017  195,29  195,68     NaN     NaN     NaN     NaN     NaN
# 2018  214,14  226,50     NaN     NaN     NaN     NaN     NaN
# 2019  186,85  189,34     NaN     NaN     NaN     NaN     NaN
# 2020  193,38  189,92     NaN     NaN     NaN     NaN     NaN
# 2021  210,84  221,00     NaN     NaN     NaN     NaN     NaN
# 2022  216,36  200,00     NaN     NaN     NaN     NaN     NaN
# 2023  208,60  214,59     NaN     NaN     NaN     NaN     NaN
# 2024     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2025     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2026     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2027     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2028     NaN     NaN     NaN     NaN     NaN     NaN     NaN

# %% [markdown]
# **Nas últimas linhas vemos que as três últimas foram usadas para informações sobre a base e mais duas linhas antes disso foram deixadas em branco. Foi necessário a eliminação das últimas 5 linhas para que não interfira na análise.**

# %%
#eliminar as últimas 5 linhas, que não tem dados.

df = df.iloc[:-5]
df.tail(20)
# Out:
#                         Produto/Unidade Nível de Comercialização U.F. 01/2023  \
# 2004                                NaN                      NaN   PE    5,00
# 2005           UVA DE MESA NIÁGARA (kg)                      NaN   PR    4,32
# 2006        UVA GAMAY SAINT ROMAIN (kg)                      NaN   RS    1,89
# 2007           UVA INDÚSTRIA BORDÔ (kg)                      NaN   MG     NaN
# 2008          UVA INDÚSTRIA ISABEL (kg)                      NaN   RS    1,45
# 2009                                NaN                      NaN   SC     NaN
# 2010  UVA INDÚSTRIA NIÁGARA BRANCA (kg)                      NaN   MG     NaN
# 2011         UVA INDÚSTRIA NIÁGARA (kg)                      NaN   SP    4,54
# 2012                   UVA MOSCATO (kg)                      NaN   RS    2,13
# 2013                   UVA NIÁGARA (kg)                      NaN   RS    1,58
# 2014                     VACA GORDA (@)                      NaN   TO  244,46
# 2015                 VACA GORDA (15 kg)                      NaN   DF  277,75
# 2016                                NaN                      NaN   GO  252,94
# 2017                                NaN                      NaN   MG  238,85
# 2018                                NaN                      NaN   MS  237,25
# 2019                                NaN                      NaN   MT  233,75
# 2020                                NaN                      NaN   PA  244,75
# 2021                                NaN                      NaN   PR  257,83
# 2022                                NaN                      NaN   SE  255,00
# 2023                                NaN                      NaN   SP  258,31
#
#      02/2023 03/2023 04/2023 05/2023 06/2023 07/2023 08/2023 09/2023 10/2023  \
# 2004    4,83    5,42    4,94    4,49    3,90    4,13    4,40    4,69    5,00
# 2005    4,39    4,99    6,20    6,33    6,42    7,21    7,22    7,19    7,29
# 2006    1,89    1,89    1,89    1,68    1,68    1,68    1,68    1,68    1,68
# 2007    5,07     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2008    1,58    1,58    1,58    1,40    1,40    1,40    1,40    1,40    1,40
# 2009    1,40    1,39    1,38    1,38     NaN     NaN     NaN     NaN     NaN
# 2010    6,36     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2011    4,15     NaN     NaN    5,22    5,07    5,56    5,58    5,98    6,32
# 2012    2,13    2,13    2,13    1,89    1,89    1,89    1,89    1,89    1,89
# 2013    1,58    1,58    1,58    1,40    1,40    1,40    1,40    1,40    1,40
# 2014  221,85  207,12  209,71  192,51  174,68  185,56     NaN     NaN     NaN
# 2015  267,00  240,65  225,50  223,00  197,09  188,33     NaN     NaN     NaN
# 2016  240,07  228,99  232,50  203,34  190,54  203,67     NaN     NaN     NaN
# 2017  243,21  237,23  241,77  216,44  195,29  195,68     NaN     NaN     NaN
# 2018  235,61  240,22  245,75  221,48  214,14  226,50     NaN     NaN     NaN
# 2019  228,28  223,74  229,08  208,89  186,85  189,34     NaN     NaN     NaN
# 2020  232,16  228,25  231,88  218,56  193,38  189,92     NaN     NaN     NaN
# 2021  252,30  251,87  254,04  231,54  210,84  221,00     NaN     NaN     NaN
# 2022  252,75  242,83  245,00  238,26  216,36  200,00     NaN     NaN     NaN
# 2023  256,87  255,37  250,75  224,06  208,60  214,59     NaN     NaN     NaN
#
#      11/2023 12/2023
# 2004    5,97    6,38
# 2005    5,77    5,35
# 2006    1,68    1,68
# 2007     NaN     NaN
# 2008    1,40    1,40
# 2009     NaN     NaN
# 2010     NaN     NaN
# 2011    6,94    6,58
# 2012    1,89    1,89
# 2013    1,40    1,40
# 2014     NaN     NaN
# 2015     NaN     NaN
# 2016     NaN     NaN
# 2017     NaN     NaN
# 2018     NaN     NaN
# 2019     NaN     NaN
# 2020     NaN     NaN
# 2021     NaN     NaN
# 2022     NaN     NaN
# 2023     NaN     NaN

# %% [markdown]
# **Para solucionar os valores nulos nas duas primeiras colunas foi necessário um comando de preenchimento.**
# **As linhas em branco foram preenchidas com o mesmo valor da primeira linha preenchida acima.**
# **As células sem valores nas colunas de preços demonstram a sazonalidade da produção e comercialização de determinados produtos agrícolas e não foram transformadas ou eliminadas.**

# %%
#preencher linhas em branco com o mesmo valor da primeira linha preenchida acima nas colunas Produto/Unidade e Nível de Comercialização

df['Produto/Unidade'] = df['Produto/Unidade'].ffill()
df['Nível de Comercialização'] = df['Nível de Comercialização'].ffill()

df.isnull().sum()
# Out:
# Produto/Unidade               0
# Nível de Comercialização      0
# U.F.                          0
# 01/2023                     123
# 02/2023                     122
# 03/2023                     150
# 04/2023                     150
# 05/2023                     140
# 06/2023                     145
# 07/2023                     172
# 08/2023                     243
# 09/2023                     259
# 10/2023                     318
# 11/2023                     421
# 12/2023                     445
# dtype: int64

# %%
#pedindo 20 linhas aleatórias de exemplo dos dados

df.sample(20)
# Out:
#                                    Produto/Unidade Nível de Comercialização  \
# 371       CAFÉ ARÁBICA TIPO 6, BEBIDA DURA (60 kg)                 PRODUTOR
# 686                                    CEBOLA (kg)                   VAREJO
# 572                 CARNE DE FRANGO RESFRIADO (kg)                  ATACADO
# 1477                            MACAÚBA FRUTO (kg)                 PRODUTOR
# 1289          LEITE DE VACA EM PÓ INTEGRAL (200 g)                   VAREJO
# 1090              FLOCOS DE MILHO ENRIQUECIDO (kg)                  ATACADO
# 991                 FEIJÃO COMUM CORES TIPO 1 (kg)                   VAREJO
# 1641                OLEO DE SOJA REFINADO (900 ml)                  ATACADO
# 1675         OVOS DE GALINHA GRANDE BRANCO (10 dz)                  ATACADO
# 1979              TRIGO PÃO, PH 75, TIPO 2 (60 kg)                 PRODUTOR
# 1554                        MILHO EM GRÃOS (60 kg)                  ATACADO
# 1349                   LEITE DE VACA IN NATURA (l)                 PRODUTOR
# 383             CAFÉ CONILLON BICA CORRIDA (60 kg)                 PRODUTOR
# 707                            COCO DE BABAÇU (m³)                 PRODUTOR
# 1293          LEITE DE VACA EM PÓ INTEGRAL (24 un)                  ATACADO
# 111                      ALHO ROXO NOBRE 5 (10 kg)                 PRODUTOR
# 773   FARINHA DE MANDIOCA GROSSA(O) D ÁGUA (30 kg)                  ATACADO
# 231                           AZEITE DE BABAÇU (l)                 PRODUTOR
# 311                            BATATA INGLESA (kg)                   VAREJO
# 1782                         POLPA DE ABACAXI (kg)                  ATACADO
#
#      U.F. 01/2023   02/2023   03/2023   04/2023 05/2023 06/2023 07/2023  \
# 371    BA  969,12  1.092,25  1.031,85  1.036,98  987,81  871,66  748,82
# 686    MG    8,61      5,57      5,51      5,36    6,35    5,25    4,99
# 572    PI   11,95     11,12     10,82     10,77   10,72   10,43   10,53
# 1477   MG    0,50      0,50      0,50      0,33    0,30    0,30    0,30
# 1289   PA    7,15      7,21      7,23      7,20    7,05    6,95    7,34
# 1090   AC    4,60      4,60      4,60      4,65    4,70    4,65    4,65
# 991    AM    8,93      8,18      9,02      9,29    8,84    8,80    8,42
# 1641   RJ    8,19      7,67      7,12      6,30    5,66    5,19    5,18
# 1675   AC   72,50     73,25     73,29     78,34   78,35   78,34   78,25
# 1979   GO  110,00    110,00    106,74     96,05   96,46   81,00   70,65
# 1554   GO   76,27     76,98     77,11     70,91   54,58   46,61   44,26
# 1349   PB    2,58      2,58      2,60      2,60    2,58    2,53    2,53
# 383    RO  628,89    628,92    594,42    586,33  602,25  617,93  575,00
# 707    TO   53,00     53,00     53,00     53,00   53,00   53,00   53,15
# 1293   AM  392,28    395,01    379,23    375,45  373,31  358,76  367,74
# 111    GO  118,75     96,00     90,00     92,50     NaN     NaN  136,25
# 773    CE  176,67    180,00    197,39    230,00  238,22  233,45  232,50
# 231    MA   20,00     20,00     22,00     23,00   25,00   25,00   25,00
# 311    SP    7,55      6,81      6,34      5,98    5,94    6,24    6,28
# 1782   SE    7,99      7,57      7,82      9,26    8,68    8,94     NaN
#
#      08/2023 09/2023 10/2023 11/2023 12/2023
# 371   775,32  766,18  761,46  818,55  908,93
# 686     4,68    4,55    4,15    5,85    5,46
# 572    10,33   11,36   11,82   11,41     NaN
# 1477    0,30     NaN     NaN    0,62    0,62
# 1289    7,03    6,76    6,31    6,73    6,23
# 1090     NaN     NaN     NaN     NaN     NaN
# 991     8,33    7,90    7,52    7,48    7,54
# 1641    5,39    5,42    5,33    5,36    6,38
# 1675   78,25   78,25   79,55   80,00   80,00
# 1979   67,03   63,36   60,75   68,49   73,67
# 1554   43,15   46,44   48,94   52,14   60,40
# 1349    2,53    2,52    2,52    2,55    2,46
# 383   586,75  572,46  571,75  588,11  626,51
# 707    54,13   53,02   54,13   53,00   53,00
# 1293  360,98  370,43  357,34  351,85     NaN
# 111   136,96  143,57  136,25  135,00  135,00
# 773   232,61  285,24  297,50  246,36  226,67
# 231    25,00   25,00   23,00   25,00   25,00
# 311     6,08    5,25     NaN     NaN     NaN
# 1782     NaN     NaN     NaN     NaN     NaN

# %% [markdown]
# **A coluna Produto/Unidade não tem a unidade padronizada, o mesmo produto pode estar em quilos, toneladas, etc., por isso foi feita a separação em duas colunas.**

# %%
#separa produto e unidade de medida e cria duas colunas. Pois, tem o mesmo produto em KG, toneladam, unidade, dúzia, litro... misturados na coluna Produto/Unidade
extracted = df['Produto/Unidade'].str.extract(r'^(.*?)\s*\(([^)]+)\)\s*$')
df['produto_nome'] = extracted[0].str.strip()
df['unidade'] = extracted[1].str.strip()
df.head(20)
# Out:
#              Produto/Unidade Nível de Comercialização U.F.   01/2023  \
# 0               ABACATE (kg)                  ATACADO   RR      6,83
# 1         ABACAXI HAVAÍ (kg)                 PRODUTOR   PR      1,85
# 2               ABACAXI (kg)                  ATACADO   RR      2,59
# 3   ABACAXI PÉROLA (6.50 kg)                 PRODUTOR   DF     21,80
# 4        ABACAXI PÉROLA (kg)                 PRODUTOR   AM      3,81
# 5        ABACAXI PÉROLA (kg)                 PRODUTOR   AP      3,20
# 6        ABACAXI PÉROLA (kg)                 PRODUTOR   ES      2,30
# 7        ABACAXI PÉROLA (kg)                 PRODUTOR   RR      2,17
# 8         ABACAXI PÉROLA (t)                 PRODUTOR   BA       NaN
# 9         ABACAXI PÉROLA (t)                 PRODUTOR   SP  1.587,50
# 10       ABACAXI PÉROLA (un)                  ATACADO   MT      3,96
# 11       ABACAXI PÉROLA (un)                 PRODUTOR   AC      3,45
# 12       ABACAXI PÉROLA (un)                 PRODUTOR   AL      1,90
# 13       ABACAXI PÉROLA (un)                 PRODUTOR   CE      5,00
# 14       ABACAXI PÉROLA (un)                 PRODUTOR   GO      3,05
# 15       ABACAXI PÉROLA (un)                 PRODUTOR   MG      1,93
# 16       ABACAXI PÉROLA (un)                 PRODUTOR   PA      2,14
# 17       ABACAXI PÉROLA (un)                 PRODUTOR   PB      2,36
# 18       ABACAXI PÉROLA (un)                 PRODUTOR   PE      1,46
# 19       ABACAXI PÉROLA (un)                 PRODUTOR   RJ      2,55
#
#      02/2023   03/2023 04/2023   05/2023   06/2023   07/2023   08/2023  \
# 0       6,67      6,83    7,00      7,00      6,00      6,00      6,60
# 1       2,31      2,30    2,30      2,30       NaN       NaN       NaN
# 2       2,65      2,79    6,00      8,00      4,50      4,50      4,95
# 3      20,14     23,45   26,65     34,82     36,87     25,47     27,36
# 4       3,75      3,75    3,90      4,00      4,25      4,02      3,94
# 5       3,40      3,40    3,55      3,72      3,81      3,63      3,43
# 6       2,56      3,04    3,35      3,36      3,27      3,13      3,11
# 7       2,13      2,24    3,62      3,93      4,14      3,90      5,74
# 8        NaN       NaN     NaN  2.000,00  1.977,27  2.050,00  2.204,35
# 9   1.744,44  1.862,50     NaN       NaN       NaN       NaN       NaN
# 10      4,41      4,52    4,41      4,47      4,39      4,91      5,00
# 11      3,45      3,45    3,46      3,93      4,00      4,03      4,05
# 12      2,16       NaN     NaN      2,40      2,81      2,66      2,89
# 13      6,00       NaN     NaN       NaN       NaN       NaN       NaN
# 14      3,42      3,08    3,48      3,67      3,46      3,25      3,17
# 15      2,68      2,60    3,45      3,43      2,81      2,85      3,44
# 16      2,50      2,50    2,33      1,63      1,20      1,23      0,87
# 17      2,36      2,53    2,53      2,53      2,53      2,53      2,53
# 18      1,90      3,95    4,10      3,30      3,52      3,28      3,08
# 19      2,58      2,82    3,62      3,50      2,92      3,07      2,50
#
#      09/2023   10/2023   11/2023 12/2023    produto_nome  unidade
# 0       7,00      7,00      7,00    7,00         ABACATE       kg
# 1        NaN       NaN      2,60    2,60   ABACAXI HAVAÍ       kg
# 2       5,00      7,50      7,00    7,50         ABACAXI       kg
# 3      28,48     31,92     25,05   25,75  ABACAXI PÉROLA  6.50 kg
# 4       4,27      4,25      4,51    4,23  ABACAXI PÉROLA       kg
# 5       3,17       NaN      3,42    3,25  ABACAXI PÉROLA       kg
# 6       3,10      3,03      3,00    3,06  ABACAXI PÉROLA       kg
# 7       6,50      6,50      6,70    6,52  ABACAXI PÉROLA       kg
# 8   2.295,24  2.325,00  2.300,00     NaN  ABACAXI PÉROLA        t
# 9        NaN       NaN       NaN     NaN  ABACAXI PÉROLA        t
# 10       NaN       NaN       NaN     NaN  ABACAXI PÉROLA       un
# 11      4,05      4,05      4,05    4,05  ABACAXI PÉROLA       un
# 12      2,74      3,15      3,27    3,59  ABACAXI PÉROLA       un
# 13       NaN       NaN      5,00    5,00  ABACAXI PÉROLA       un
# 14      2,91      3,03      2,82    3,63  ABACAXI PÉROLA       un
# 15      3,52      3,60      3,69    3,20  ABACAXI PÉROLA       un
# 16      0,80      0,80      1,09    2,86  ABACAXI PÉROLA       un
# 17      2,37      2,50      2,50    2,57  ABACAXI PÉROLA       un
# 18      3,05      3,25      3,73    3,93  ABACAXI PÉROLA       un
# 19      2,42      2,52      2,99    4,43  ABACAXI PÉROLA       un

# %% [markdown]
# **Os preços não estão em formato numérico, foi necessário um comando para conversão.**

# %%
#converte os preços de texto para número
meses = ['01/2023','02/2023','03/2023','04/2023','05/2023','06/2023',
         '07/2023','08/2023','09/2023','10/2023','11/2023','12/2023']

for col in meses:
    df[col] = (df[col].astype(str)
                       .str.replace('.', '', regex=False)
                       .str.replace(',', '.', regex=False)
                       .replace('nan', np.nan)
                       .astype(float))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2024 entries, 0 to 2023
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Produto/Unidade           2024 non-null   object
#  1   Nível de Comercialização  2024 non-null   object
#  2   U.F.                      2024 non-null   object
#  3   01/2023                   1901 non-null   float64
#  4   02/2023                   1902 non-null   float64
#  5   03/2023                   1874 non-null   float64
#  6   04/2023                   1874 non-null   float64
#  7   05/2023                   1884 non-null   float64
#  8   06/2023                   1879 non-null   float64
#  9   07/2023                   1852 non-null   float64
#  10  08/2023                   1781 non-null   float64
#  11  09/2023                   1765 non-null   float64
#  12  10/2023                   1706 non-null   float64
#  13  11/2023                   1603 non-null   float64
#  14  12/2023                   1579 non-null   float64
#  15  produto_nome              2024 non-null   object
#  16  unidade                   2024 non-null   object
# dtypes: float64(12), object(5)
# memory usage: 268.9+ KB

# %% [markdown]
# **Os preços são apresentados em 12 colunas referentes aos meses, isso pode dificultar a análise. Então as 12 colunas foram transformadas em duas, uma contendo o mês e outra contendo o preço.**

# %%
#transforma as 12 colunas de mês em 2 colunas: mes_ano e preco_medio(daquele mês)

df_novo = df.melt(
    id_vars=['produto_nome', 'unidade', 'Nível de Comercialização', 'U.F.'],
    value_vars=meses,
    var_name='mes_ano',
    value_name='preco_medio'
)
df_novo.head(20)
# Out:
#       produto_nome  unidade Nível de Comercialização U.F.  mes_ano  \
# 0          ABACATE       kg                  ATACADO   RR  01/2023
# 1    ABACAXI HAVAÍ       kg                 PRODUTOR   PR  01/2023
# 2          ABACAXI       kg                  ATACADO   RR  01/2023
# 3   ABACAXI PÉROLA  6.50 kg                 PRODUTOR   DF  01/2023
# 4   ABACAXI PÉROLA       kg                 PRODUTOR   AM  01/2023
# 5   ABACAXI PÉROLA       kg                 PRODUTOR   AP  01/2023
# 6   ABACAXI PÉROLA       kg                 PRODUTOR   ES  01/2023
# 7   ABACAXI PÉROLA       kg                 PRODUTOR   RR  01/2023
# 8   ABACAXI PÉROLA        t                 PRODUTOR   BA  01/2023
# 9   ABACAXI PÉROLA        t                 PRODUTOR   SP  01/2023
# 10  ABACAXI PÉROLA       un                  ATACADO   MT  01/2023
# 11  ABACAXI PÉROLA       un                 PRODUTOR   AC  01/2023
# 12  ABACAXI PÉROLA       un                 PRODUTOR   AL  01/2023
# 13  ABACAXI PÉROLA       un                 PRODUTOR   CE  01/2023
# 14  ABACAXI PÉROLA       un                 PRODUTOR   GO  01/2023
# 15  ABACAXI PÉROLA       un                 PRODUTOR   MG  01/2023
# 16  ABACAXI PÉROLA       un                 PRODUTOR   PA  01/2023
# 17  ABACAXI PÉROLA       un                 PRODUTOR   PB  01/2023
# 18  ABACAXI PÉROLA       un                 PRODUTOR   PE  01/2023
# 19  ABACAXI PÉROLA       un                 PRODUTOR   RJ  01/2023
#
#     preco_medio
# 0          6.83
# 1          1.85
# 2          2.59
# 3         21.80
# 4          3.81
# 5          3.20
# 6          2.30
# 7          2.17
# 8           NaN
# 9       1587.50
# 10         3.96
# 11         3.45
# 12         1.90
# 13         5.00
# 14         3.05
# 15         1.93
# 16         2.14
# 17         2.36
# 18         1.46
# 19         2.55

# %% [markdown]
# **Para ampliar as possibilidades de análise foi criada uma nova colunas, contendo a região geográfica à qual o estado pertence.**

# %%
regiao_map = {
    'AC':'Norte','AP':'Norte','AM':'Norte','PA':'Norte','RO':'Norte','RR':'Norte','TO':'Norte',
    'AL':'Nordeste','BA':'Nordeste','CE':'Nordeste','MA':'Nordeste','PB':'Nordeste',
    'PE':'Nordeste','PI':'Nordeste','RN':'Nordeste','SE':'Nordeste',
    'DF':'Centro-Oeste','GO':'Centro-Oeste','MT':'Centro-Oeste','MS':'Centro-Oeste',
    'ES':'Sudeste','MG':'Sudeste','RJ':'Sudeste','SP':'Sudeste',
    'PR':'Sul','RS':'Sul','SC':'Sul'
}
df_regiao = pd.DataFrame(list(regiao_map.items()), columns=['U.F.', 'regiao'])

linhas_antes = len(df_novo)
df_novo = df_novo.merge(df_regiao, on='U.F.', how='left')
print(linhas_antes, len(df_novo))  # confere se bateu — sem duplicar linha
# Out:
# 24288 24288

# %%
df_novo.head(20)
# Out:
#       produto_nome  unidade Nível de Comercialização U.F.  mes_ano  \
# 0          ABACATE       kg                  ATACADO   RR  01/2023
# 1    ABACAXI HAVAÍ       kg                 PRODUTOR   PR  01/2023
# 2          ABACAXI       kg                  ATACADO   RR  01/2023
# 3   ABACAXI PÉROLA  6.50 kg                 PRODUTOR   DF  01/2023
# 4   ABACAXI PÉROLA       kg                 PRODUTOR   AM  01/2023
# 5   ABACAXI PÉROLA       kg                 PRODUTOR   AP  01/2023
# 6   ABACAXI PÉROLA       kg                 PRODUTOR   ES  01/2023
# 7   ABACAXI PÉROLA       kg                 PRODUTOR   RR  01/2023
# 8   ABACAXI PÉROLA        t                 PRODUTOR   BA  01/2023
# 9   ABACAXI PÉROLA        t                 PRODUTOR   SP  01/2023
# 10  ABACAXI PÉROLA       un                  ATACADO   MT  01/2023
# 11  ABACAXI PÉROLA       un                 PRODUTOR   AC  01/2023
# 12  ABACAXI PÉROLA       un                 PRODUTOR   AL  01/2023
# 13  ABACAXI PÉROLA       un                 PRODUTOR   CE  01/2023
# 14  ABACAXI PÉROLA       un                 PRODUTOR   GO  01/2023
# 15  ABACAXI PÉROLA       un                 PRODUTOR   MG  01/2023
# 16  ABACAXI PÉROLA       un                 PRODUTOR   PA  01/2023
# 17  ABACAXI PÉROLA       un                 PRODUTOR   PB  01/2023
# 18  ABACAXI PÉROLA       un                 PRODUTOR   PE  01/2023
# 19  ABACAXI PÉROLA       un                 PRODUTOR   RJ  01/2023
#
#     preco_medio        regiao
# 0          6.83         Norte
# 1          1.85           Sul
# 2          2.59         Norte
# 3         21.80  Centro-Oeste
# 4          3.81         Norte
# 5          3.20         Norte
# 6          2.30       Sudeste
# 7          2.17         Norte
# 8           NaN      Nordeste
# 9       1587.50       Sudeste
# 10         3.96  Centro-Oeste
# 11         3.45         Norte
# 12         1.90      Nordeste
# 13         5.00      Nordeste
# 14         3.05  Centro-Oeste
# 15         1.93       Sudeste
# 16         2.14         Norte
# 17         2.36      Nordeste
# 18         1.46      Nordeste
# 19         2.55       Sudeste

# %% [markdown]
# ## Análise 1: Qual produto apresentou o maior aumento percentual entre janeiro e dezembro de 2023?

# %%
# Filtrar apenas janeiro e dezembro
df_jan = df_novo[df_novo['mes_ano'] == '01/2023']
df_dez = df_novo[df_novo['mes_ano'] == '12/2023']

# Agrupar por produto e unidade para ter o preço médio nacional em cada mês
preco_jan = df_jan.groupby(['produto_nome', 'unidade'])['preco_medio'].mean().reset_index(name='preco_jan')
preco_dez = df_dez.groupby(['produto_nome', 'unidade'])['preco_medio'].mean().reset_index(name='preco_dez')

# Juntar as duas tabelas
variacao = pd.merge(preco_jan, preco_dez, on=['produto_nome', 'unidade'])

# Calcular a variação percentual
variacao['variacao_pct'] = (variacao['preco_dez'] - variacao['preco_jan']) / variacao['preco_jan'] * 100

# Produto com maior aumento
top_produto = variacao.loc[variacao['variacao_pct'].idxmax()]
print(f"Produto com maior aumento: {top_produto['produto_nome']} ({top_produto['unidade']})")
print(f"Aumento de {top_produto['variacao_pct']:.2f}% (de R${top_produto['preco_jan']:.2f} para R${top_produto['preco_dez']:.2f})")

# Visualizar os 10 maiores aumentos
top10 = variacao.nlargest(10, 'variacao_pct')
plt.figure(figsize=(10,6))
plt.barh(top10['produto_nome'] + ' (' + top10['unidade'] + ')', top10['variacao_pct'])
plt.xlabel('Variação percentual (%)')
plt.title('Top 10 produtos com maior aumento de preço (jan → dez 2023)')
plt.tight_layout()
plt.show()
# Out:
# Produto com maior aumento: FARINHA DE TRIGO ESPECIAL (kg)
# Aumento de 7097.28% (de R$6.31 para R$454.51)

# %% [markdown]
# **Aqui podemos observar um valor bem discrepante para a Farinha de trigo especial.**

# %%
df_novo[
    (df_novo['produto_nome'] == 'FARINHA DE TRIGO ESPECIAL') & (df_novo['unidade'] == 'kg')
].sort_values('preco_medio', ascending=False)
# Out:
#                     produto_nome unidade Nível de Comercialização U.F.  \
# 23150  FARINHA DE TRIGO ESPECIAL      kg                  ATACADO   SP
# 13031  FARINHA DE TRIGO ESPECIAL      kg                   VAREJO   CE
# 8983   FARINHA DE TRIGO ESPECIAL      kg                   VAREJO   CE
# 11007  FARINHA DE TRIGO ESPECIAL      kg                   VAREJO   CE
# 2911   FARINHA DE TRIGO ESPECIAL      kg                   VAREJO   CE
# ...                          ...     ...                      ...  ...
# 13030  FARINHA DE TRIGO ESPECIAL      kg                  ATACADO   SP
# 15054  FARINHA DE TRIGO ESPECIAL      kg                  ATACADO   SP
# 17078  FARINHA DE TRIGO ESPECIAL      kg                  ATACADO   SP
# 19102  FARINHA DE TRIGO ESPECIAL      kg                  ATACADO   SP
# 21126  FARINHA DE TRIGO ESPECIAL      kg                  ATACADO   SP
#
#        mes_ano  preco_medio    regiao
# 23150  12/2023      4948.00   Sudeste
# 13031  07/2023        10.15  Nordeste
# 8983   05/2023         9.91  Nordeste
# 11007  06/2023         9.85  Nordeste
# 2911   02/2023         9.67  Nordeste
# ...        ...          ...       ...
# 13030  07/2023          NaN   Sudeste
# 15054  08/2023          NaN   Sudeste
# 17078  09/2023          NaN   Sudeste
# 19102  10/2023          NaN   Sudeste
# 21126  11/2023          NaN   Sudeste
#
# [132 rows x 7 columns]

# %%
**O valor mais alto vem de um preço de atacado que provavelmente está com a unidade errada, deveria ser tonelada e está em quilograma. Para melhorar a análise, vamos separar os preços por nível de comercialização.**

# %%
# Filtrar apenas janeiro e dezembro
df_jan = df_novo[df_novo['mes_ano'] == '01/2023']
df_dez = df_novo[df_novo['mes_ano'] == '12/2023']

# Agrupar por produto e unidade para ter o preço médio nacional em cada mês
preco_jan = df_jan.groupby(['produto_nome', 'unidade', 'Nível de Comercialização'])['preco_medio'].mean().reset_index(name='preco_jan')
preco_dez = df_dez.groupby(['produto_nome', 'unidade', 'Nível de Comercialização'])['preco_medio'].mean().reset_index(name='preco_dez')

# Juntar as duas tabelas
variacao = pd.merge(preco_jan, preco_dez, on=['produto_nome', 'unidade', 'Nível de Comercialização'])

# Calcular a variação percentual
variacao['variacao_pct'] = (variacao['preco_dez'] - variacao['preco_jan']) / variacao['preco_jan'] * 100

# Produto com maior aumento
top_produto = variacao.loc[variacao['variacao_pct'].idxmax()]
print(f"Produto com maior aumento: {top_produto['produto_nome']} ({top_produto['unidade']})")
print(f"Aumento de {top_produto['variacao_pct']:.2f}% (de R${top_produto['preco_jan']:.2f} para R${top_produto['preco_dez']:.2f})")

# Visualizar os 10 maiores aumentos
top10 = variacao.nlargest(10, 'variacao_pct')
plt.figure(figsize=(10,6))
plt.barh(top10['produto_nome'] + ' (' + top10['unidade'] + ')', top10['variacao_pct'])
plt.xlabel('Variação percentual (%)')
plt.title('Top 10 produtos com maior aumento de preço (jan → dez 2023)')
plt.tight_layout()
plt.show()
# Out:
# Produto com maior aumento: PEQUI COM CASCA (kg)
# Aumento de 1487.83% (de R$0.63 para R$10.00)

# %% [markdown]
# **Vamos analisar qual a origem da grande variação do pequi.**

# %%
df_novo[
    (df_novo['produto_nome'] == 'PEQUI COM CASCA') & (df_novo['unidade'] == 'kg')
].sort_values('preco_medio', ascending=False)
# Out:
#           produto_nome unidade Nível de Comercialização U.F.  mes_ano  \
# 24012  PEQUI COM CASCA      kg                 PRODUTOR   CE  12/2023
# 24011  PEQUI COM CASCA      kg                 PRODUTOR   BA  12/2023
# 7820   PEQUI COM CASCA      kg                 PRODUTOR   CE  04/2023
# 5796   PEQUI COM CASCA      kg                 PRODUTOR   CE  03/2023
# 3772   PEQUI COM CASCA      kg                 PRODUTOR   CE  02/2023
# 21989  PEQUI COM CASCA      kg                 PRODUTOR   GO  11/2023
# 24013  PEQUI COM CASCA      kg                 PRODUTOR   GO  12/2023
# 17942  PEQUI COM CASCA      kg                 PRODUTOR   MG  09/2023
# 15918  PEQUI COM CASCA      kg                 PRODUTOR   MG  08/2023
# 3774   PEQUI COM CASCA      kg                 PRODUTOR   MG  02/2023
# 1751   PEQUI COM CASCA      kg                 PRODUTOR   PI  01/2023
# 1750   PEQUI COM CASCA      kg                 PRODUTOR   MG  01/2023
# 7823   PEQUI COM CASCA      kg                 PRODUTOR   PI  04/2023
# 5799   PEQUI COM CASCA      kg                 PRODUTOR   PI  03/2023
# 3775   PEQUI COM CASCA      kg                 PRODUTOR   PI  02/2023
# 1747   PEQUI COM CASCA      kg                 PRODUTOR   BA  01/2023
# 1748   PEQUI COM CASCA      kg                 PRODUTOR   CE  01/2023
# 1749   PEQUI COM CASCA      kg                 PRODUTOR   GO  01/2023
# 3771   PEQUI COM CASCA      kg                 PRODUTOR   BA  02/2023
# 3773   PEQUI COM CASCA      kg                 PRODUTOR   GO  02/2023
# 5795   PEQUI COM CASCA      kg                 PRODUTOR   BA  03/2023
# 5797   PEQUI COM CASCA      kg                 PRODUTOR   GO  03/2023
# 5798   PEQUI COM CASCA      kg                 PRODUTOR   MG  03/2023
# 7819   PEQUI COM CASCA      kg                 PRODUTOR   BA  04/2023
# 7821   PEQUI COM CASCA      kg                 PRODUTOR   GO  04/2023
# 7822   PEQUI COM CASCA      kg                 PRODUTOR   MG  04/2023
# 9843   PEQUI COM CASCA      kg                 PRODUTOR   BA  05/2023
# 9844   PEQUI COM CASCA      kg                 PRODUTOR   CE  05/2023
# 9845   PEQUI COM CASCA      kg                 PRODUTOR   GO  05/2023
# 9846   PEQUI COM CASCA      kg                 PRODUTOR   MG  05/2023
# 9847   PEQUI COM CASCA      kg                 PRODUTOR   PI  05/2023
# 11867  PEQUI COM CASCA      kg                 PRODUTOR   BA  06/2023
# 11868  PEQUI COM CASCA      kg                 PRODUTOR   CE  06/2023
# 11869  PEQUI COM CASCA      kg                 PRODUTOR   GO  06/2023
# 11870  PEQUI COM CASCA      kg                 PRODUTOR   MG  06/2023
# 11871  PEQUI COM CASCA      kg                 PRODUTOR   PI  06/2023
# 13891  PEQUI COM CASCA      kg                 PRODUTOR   BA  07/2023
# 13892  PEQUI COM CASCA      kg                 PRODUTOR   CE  07/2023
# 13893  PEQUI COM CASCA      kg                 PRODUTOR   GO  07/2023
# 13894  PEQUI COM CASCA      kg                 PRODUTOR   MG  07/2023
# 13895  PEQUI COM CASCA      kg                 PRODUTOR   PI  07/2023
# 15915  PEQUI COM CASCA      kg                 PRODUTOR   BA  08/2023
# 15916  PEQUI COM CASCA      kg                 PRODUTOR   CE  08/2023
# 15917  PEQUI COM CASCA      kg                 PRODUTOR   GO  08/2023
# 15919  PEQUI COM CASCA      kg                 PRODUTOR   PI  08/2023
# 17939  PEQUI COM CASCA      kg                 PRODUTOR   BA  09/2023
# 17940  PEQUI COM CASCA      kg                 PRODUTOR   CE  09/2023
# 17941  PEQUI COM CASCA      kg                 PRODUTOR   GO  09/2023
# 17943  PEQUI COM CASCA      kg                 PRODUTOR   PI  09/2023
# 19963  PEQUI COM CASCA      kg                 PRODUTOR   BA  10/2023
# 19964  PEQUI COM CASCA      kg                 PRODUTOR   CE  10/2023
# 19965  PEQUI COM CASCA      kg                 PRODUTOR   GO  10/2023
# 19966  PEQUI COM CASCA      kg                 PRODUTOR   MG  10/2023
# 19967  PEQUI COM CASCA      kg                 PRODUTOR   PI  10/2023
# 21987  PEQUI COM CASCA      kg                 PRODUTOR   BA  11/2023
# 21988  PEQUI COM CASCA      kg                 PRODUTOR   CE  11/2023
# 21990  PEQUI COM CASCA      kg                 PRODUTOR   MG  11/2023
# 21991  PEQUI COM CASCA      kg                 PRODUTOR   PI  11/2023
# 24014  PEQUI COM CASCA      kg                 PRODUTOR   MG  12/2023
# 24015  PEQUI COM CASCA      kg                 PRODUTOR   PI  12/2023
#
#        preco_medio        regiao
# 24012        20.42      Nordeste
# 24011         8.03      Nordeste
# 7820          2.88      Nordeste
# 5796          1.75      Nordeste
# 3772          1.74      Nordeste
# 21989         1.56  Centro-Oeste
# 24013         1.56  Centro-Oeste
# 17942         1.30       Sudeste
# 15918         1.04       Sudeste
# 3774          0.83       Sudeste
# 1751          0.66      Nordeste
# 1750          0.60       Sudeste
# 7823          0.48      Nordeste
# 5799          0.44      Nordeste
# 3775          0.36      Nordeste
# 1747           NaN      Nordeste
# 1748           NaN      Nordeste
# 1749           NaN  Centro-Oeste
# 3771           NaN      Nordeste
# 3773           NaN  Centro-Oeste
# 5795           NaN      Nordeste
# 5797           NaN  Centro-Oeste
# 5798           NaN       Sudeste
# 7819           NaN      Nordeste
# 7821           NaN  Centro-Oeste
# 7822           NaN       Sudeste
# 9843           NaN      Nordeste
# 9844           NaN      Nordeste
# 9845           NaN  Centro-Oeste
# 9846           NaN       Sudeste
# 9847           NaN      Nordeste
# 11867          NaN      Nordeste
# 11868          NaN      Nordeste
# 11869          NaN  Centro-Oeste
# 11870          NaN       Sudeste
# 11871          NaN      Nordeste
# 13891          NaN      Nordeste
# 13892          NaN      Nordeste
# 13893          NaN  Centro-Oeste
# 13894          NaN       Sudeste
# 13895          NaN      Nordeste
# 15915          NaN      Nordeste
# 15916          NaN      Nordeste
# 15917          NaN  Centro-Oeste
# 15919          NaN      Nordeste
# 17939          NaN      Nordeste
# 17940          NaN      Nordeste
# 17941          NaN  Centro-Oeste
# 17943          NaN      Nordeste
# 19963          NaN      Nordeste
# 19964          NaN      Nordeste
# 19965          NaN  Centro-Oeste
# 19966          NaN       Sudeste
# 19967          NaN      Nordeste
# 21987          NaN      Nordeste
# 21988          NaN      Nordeste
# 21990          NaN       Sudeste
# 21991          NaN      Nordeste
# 24014          NaN       Sudeste
# 24015          NaN      Nordeste

# %% [markdown]
# **Existe uma grande variação por estado, vamos refazer a análise separando também por estados.**

# %%
# Filtrar apenas janeiro e dezembro
df_jan = df_novo[df_novo['mes_ano'] == '01/2023']
df_dez = df_novo[df_novo['mes_ano'] == '12/2023']

# Agrupar por produto e unidade para ter o preço médio nacional em cada mês
preco_jan = df_jan.groupby(['produto_nome', 'unidade', 'Nível de Comercialização', 'U.F.'])['preco_medio'].mean().reset_index(name='preco_jan')
preco_dez = df_dez.groupby(['produto_nome', 'unidade', 'Nível de Comercialização', 'U.F.'])['preco_medio'].mean().reset_index(name='preco_dez')

# Juntar as duas tabelas
variacao = pd.merge(preco_jan, preco_dez, on=['produto_nome', 'unidade', 'Nível de Comercialização', 'U.F.'])

# Calcular a variação percentual
variacao['variacao_pct'] = (variacao['preco_dez'] - variacao['preco_jan']) / variacao['preco_jan'] * 100

# Produto com maior aumento
top_produto = variacao.loc[variacao['variacao_pct'].idxmax()]
print(f"Produto com maior aumento: {top_produto['produto_nome']} ({top_produto['unidade']})")
print(f"Aumento de {top_produto['variacao_pct']:.2f}% (de R${top_produto['preco_jan']:.2f} para R${top_produto['preco_dez']:.2f})")

# Visualizar os 10 maiores aumentos
top10 = variacao.nlargest(10, 'variacao_pct')
plt.figure(figsize=(10,6))
plt.barh(top10['produto_nome'] + ' (' + top10['unidade'] + ')' + ' (' + top10['U.F.'] + ')', top10['variacao_pct'])
plt.xlabel('Variação percentual (%)')
plt.title('Top 10 produtos com maior aumento de preço (jan → dez 2023)')
plt.tight_layout()
plt.show()
# Out:
# Produto com maior aumento: MANGABA FRUTO (kg)
# Aumento de 376.19% (de R$1.05 para R$5.00)

# %% [markdown]
# ## Análise 2: Qual região teve o preço médio mais alto para "ABACAXI PÉROLA (kg)" em 2023?

# %%
# Filtrar o produto específico
abacaxi = df_novo[(df_novo['produto_nome'] == 'ABACAXI PÉROLA') & (df_novo['unidade'] == 'kg')]

# Calcular a média anual por região
media_regiao = abacaxi.groupby('regiao')['preco_medio'].mean().reset_index()
media_regiao = media_regiao.sort_values('preco_medio', ascending=False)

# Exibir
print("Preço médio anual da ABACAXI PÉROLA (kg) por região:")
print(media_regiao)

# Região com maior preço
maior = media_regiao.iloc[0]
print(f"\nRegião com maior preço médio: {maior['regiao']} (R${maior['preco_medio']:.2f})")

# Gráfico de barras
plt.figure(figsize=(8,5))
plt.bar(media_regiao['regiao'], media_regiao['preco_medio'], color='orange')
plt.ylabel('Preço médio (R$)')
plt.title('Preço médio da ABACAXI PÉROLA (kg) por região em 2023')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Preço médio anual da ABACAXI PÉROLA (kg) por região:
#     regiao  preco_medio
# 0    Norte     4.021429
# 1  Sudeste     3.025833
#
# Região com maior preço médio: Norte (R$4.02)

# %% [markdown]
# ## Análise 3: Existe sazonalidade no preço do ABACATE (kg) ao longo dos meses?

# %%
# Filtrar abacate em kg
abacate = df_novo[(df_novo['produto_nome'] == 'ABACATE') & (df_novo['unidade'] == 'kg')]

# Calcular a média nacional por mês (considerando todas as UFs e níveis)
media_mensal = abacate.groupby('mes_ano')['preco_medio'].mean().reset_index()

# Ordenar cronologicamente (já que mes_ano está como string, converter para data)
media_mensal['mes_num'] = pd.to_datetime(media_mensal['mes_ano'], format='%m/%Y').dt.month
media_mensal = media_mensal.sort_values('mes_num')

# Gráfico de linha
plt.figure(figsize=(10,5))
plt.plot(media_mensal['mes_ano'], media_mensal['preco_medio'], marker='o', linestyle='-')
plt.ylabel('Preço médio nacional (R$)')
plt.xlabel('Mês')
plt.title('Variação mensal do preço do ABACATE (kg) em 2023')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# Estatísticas
print("Preço médio por mês:")
print(media_mensal)
print(f"\nMês com maior preço: {media_mensal.loc[media_mensal['preco_medio'].idxmax(), 'mes_ano']} (R${media_mensal['preco_medio'].max():.2f})")
print(f"Mês com menor preço: {media_mensal.loc[media_mensal['preco_medio'].idxmin(), 'mes_ano']} (R${media_mensal['preco_medio'].min():.2f})")
# Out:
# Preço médio por mês:
#     mes_ano  preco_medio  mes_num
# 0   01/2023         6.83        1
# 1   02/2023         6.67        2
# 2   03/2023         6.83        3
# 3   04/2023         7.00        4
# 4   05/2023         7.00        5
# 5   06/2023         6.00        6
# 6   07/2023         6.00        7
# 7   08/2023         6.60        8
# 8   09/2023         7.00        9
# 9   10/2023         7.00       10
# 10  11/2023         7.00       11
# 11  12/2023         7.00       12
#
# Mês com maior preço: 04/2023 (R$7.00)
# Mês com menor preço: 06/2023 (R$6.00)

# %% [markdown]
# ## Análise 4: O preço do arroz no atacado é diferente do varejo?

# %%
# Filtrar produtos que contenham "ARROZ" (exemplo: ARROZ LONGO FINO...) e unidade 'kg'
arroz = df_novo[(df_novo['produto_nome'].str.contains('ARROZ', case=False)) & (df_novo['unidade'] == 'kg')]

# Calcular média por nível de comercialização
media_nivel = arroz.groupby('Nível de Comercialização')['preco_medio'].mean().reset_index()

print("Preço médio do arroz (kg) por nível de comercialização:")
print(media_nivel)

# Gráfico
plt.figure(figsize=(8,5))
plt.bar(media_nivel['Nível de Comercialização'], media_nivel['preco_medio'], color=['green', 'blue', 'red'])
plt.ylabel('Preço médio (R$)')
plt.xlabel('Nível de Comercialização')
plt.title('Comparação de preços do arroz (kg) por canal')
for i, row in media_nivel.iterrows():
    plt.text(row['Nível de Comercialização'], row['preco_medio']+0.5, f'R${row["preco_medio"]:.2f}', ha='center')
plt.tight_layout()
plt.show()

# Comparação direta (atacado vs varejo)
if 'ATACADO' in media_nivel['Nível de Comercialização'].values and 'VAREJO' in media_nivel['Nível de Comercialização'].values:
    preco_atacado = media_nivel[media_nivel['Nível de Comercialização'] == 'ATACADO']['preco_medio'].values[0]
    preco_varejo = media_nivel[media_nivel['Nível de Comercialização'] == 'VAREJO']['preco_medio'].values[0]
    diferenca_pct = (preco_varejo - preco_atacado) / preco_atacado * 100
    print(f"\nO varejo é {diferenca_pct:.2f}% mais caro que o atacado.")
# Out:
# Preço médio do arroz (kg) por nível de comercialização:
#   Nível de Comercialização  preco_medio
# 0                  ATACADO     4.765000
# 1                   VAREJO     5.198041
# O varejo é 9.09% mais caro que o atacado.

# %% [markdown]
# ## Análise 5: Quais foram os 5 meses com maior preço médio geral (todos os produtos e UFs)?

# %%
# Média geral simples por mês (sem ponderação por volume de vendas – apenas a média dos preços registrados)
media_geral_mes = df_novo.groupby('mes_ano')['preco_medio'].mean().reset_index()

# Ordenar e pegar os 5 maiores
top5_meses = media_geral_mes.nlargest(5, 'preco_medio')

print("5 meses com maior preço médio geral (todos os produtos):")
print(top5_meses)

# Gráfico de barras
plt.figure(figsize=(8,5))
plt.bar(top5_meses['mes_ano'], top5_meses['preco_medio'], color='purple')
plt.ylabel('Preço médio geral (R$)')
plt.xlabel('Mês')
plt.title('Top 5 meses com maior preço médio em 2023')
for i, row in top5_meses.iterrows():
    plt.text(row['mes_ano'], row['preco_medio']+0.5, f'R${row["preco_medio"]:.2f}', ha='center')
plt.tight_layout()
plt.show()
# Out:
# 5 meses com maior preço médio geral (todos os produtos):
#    mes_ano  preco_medio
# 2  03/2023   101.696596
# 1  02/2023   101.015315
# 0  01/2023   100.773845
# 3  04/2023   100.485043
# 4  05/2023    98.730324
